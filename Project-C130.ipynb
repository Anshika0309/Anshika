# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshika0309/Anshika/blob/main/Project-C130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb05d240-ee1c-4f8c-8507-d8d5204ecd8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb05d240-ee1c-4f8c-8507-d8d5204ecd8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('total_stars.csv')
print(df.shape)
# Out:
# (255, 12)

# %%
df.head()
# Out:
#    id       Star_name     Distance Mass Radius Luminosity  Unnamed: 6  id.1  \
# 0   0             Sun  0.000015813    1      1          1         NaN   NaN
# 1   1          Sirius       0008.6  2.1   1.71       25.4         NaN   NaN
# 2   2         Canopus         0310   15     71     13,500         NaN   NaN
# 3   3  Alpha Centauri       0004.4  1.1    1.2          2         NaN   NaN
# 4   4        Arcturus         0037  1.1     26        170         NaN   NaN
#
#    Star_name.1  Distance.1  Mass.1  Radius.1
# 0          NaN         NaN     NaN       NaN
# 1          NaN         NaN     NaN       NaN
# 2          NaN         NaN     NaN       NaN
# 3          NaN         NaN     NaN       NaN
# 4          NaN         NaN     NaN       NaN

# %%
df.columns
# Out:
# Index(['id', 'Star_name', 'Distance', 'Mass', 'Radius', 'Luminosity',
#        'Unnamed: 6', 'id.1', 'Star_name.1', 'Distance.1', 'Mass.1',
#        'Radius.1'],
#       dtype='object')

# %%
df.drop(columns = ['Luminosity'],inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'Star_name', 'Distance', 'Mass', 'Radius', 'Unnamed: 6', 'id.1',
#        'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1'],
#       dtype='object')

# %%
df.shape
# Out:
# (255, 11)

# %%
df.dropna(inplace=True, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         255 non-null    int64
#  1   Star_name  255 non-null    object
#  2   Distance   255 non-null    object
#  3   Radius     255 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.1+ KB

# %%
df.describe()
# Out:
#                id
# count  255.000000
# mean    80.576471
# std     55.735747
# min      0.000000
# 25%     36.000000
# 50%     71.000000
# 75%    121.500000
# max    284.000000

# %%
df.head()
# Out:
#    id       Star_name     Distance Radius
# 0   0             Sun  0.000015813      1
# 1   1          Sirius       0008.6   1.71
# 2   2         Canopus         0310     71
# 3   3  Alpha Centauri       0004.4    1.2
# 4   4        Arcturus         0037     26

# %%
df.to_csv('final_data.csv')

# %%
from google.colab import files
files.download('final_data.csv')
